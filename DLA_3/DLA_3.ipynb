# %% [markdown]
# # DLA 3 - Apprendimento per rinforzo profondo
#
# Autore: Francesco Faggioli
# Corso: Deep Learning Applications
#
# [Consegna ufficiale](ASSIGNMENT.md) | [Report tecnico](README.md)

# %% [markdown]
# > **Modalita' di consultazione**
# >
# > Questo notebook e' l'indice GitHub-ready. I risultati eseguiti restano nei notebook dettagliati; training, rendering e valutazioni lunghe sono disattivati di default.

# %% [markdown]
# ## Percorso finale
#
# | Notebook | Ruolo | Evidenza principale |
# | --- | --- | --- |
# | `notebooks/01_cartpole_reinforce_evaluation.ipynb` | REINFORCE e valutazione periodica | Best return 489.35 |
# | `notebooks/02_cartpole_value_baseline.ipynb` | Baseline con value network | Final return 500.0 |
# | `notebooks/03_a2c_cartpole_lunarlander.ipynb` | A2C CartPole/LunarLander | LunarLander 165.76, successo 56% |
#
# Le prove storiche sono separate in `exploratory/00_esperimenti_di_prova_a2c.ipynb`.

# %% [markdown]
# ## Risultato sintetico
#
# ![Valutazione LunarLander](figures/lunarlander_final_evaluation.svg)
#
# Fonte numerica: [`results/lunarlander_final_evaluation.json`](results/lunarlander_final_evaluation.json).

# %% [markdown]
# ## Controlli visuali opzionali
#
# | Ambiente | Modello | Episodi | Evidenza leggera |
# | --- | --- | ---: | --- |
# | CartPole-v1 | REINFORCE con baseline di valore, greedy | 5 | [`results/cartpole_visual_episodes.json`](results/cartpole_visual_episodes.json) |
# | LunarLander-v3 | A2C finale, sample T=0.75 | 5 | [`results/lunarlander_visual_episodes.json`](results/lunarlander_visual_episodes.json) |
#
# I flag di rendering sono disattivati per la consegna. Le animazioni sono visualizzabili localmente dai notebook dettagliati, mentre i video HTML pesanti non sono inclusi.

# %% [markdown]
# ## Funzioni, classi e moduli locali richiamati
#
# La tabella è ricavata dagli import, dagli utilizzi nelle celle e dalle definizioni effettive nei package locali.
#
# | Funzione o classe | Tipo | File di definizione | Scopo | Input principali | Output principali | Sezione |
# | ----------------- | ---- | ------------------- | ----- | ---------------- | ----------------- | ------- |
# | Nessuna funzione locale (notebook indice) | — | — | Collega documentazione e notebook tecnici. | — | — | Indice |
