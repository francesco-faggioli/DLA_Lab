# %% [markdown]
# # DLA 1 - Visione artificiale su GTSRB
#
# Autore: Francesco Faggioli
# Corso: Deep Learning Applications
#
# [Consegna ufficiale](ASSIGNMENT.md) | [Report tecnico](README.md)

# %% [markdown]
# > **Modalita' di consultazione**
# >
# > Questo notebook e' l'indice GitHub-ready. Gli output sperimentali sono nei notebook dettagliati, mentre `results/` contiene evidenze leggere versionate. I training lunghi sono disattivati di default.

# %% [markdown]
# ## Percorso finale
#
# | Notebook | Ruolo | Evidenza principale |
# | --- | --- | --- |
# | `notebooks/01_eda_and_feature_baseline.ipynb` | EDA e ResNet-18 + SVM | Accuracy di test 0.6412 |
# | `notebooks/02_finetuning_pipeline.ipynb` | Fine-tuning baseline | Accuracy di test 0.5038 |
# | `notebooks/02b_pipeline_consolidation.ipynb` | Pipeline e W&B opzionale | Configurazioni e tracking |
# | `notebooks/03_improvements_and_retrieval.ipynb` | Fine-tuning migliorato | Accuracy di test 0.8025 |
# | `notebooks/03b_retrieval_training_free_classification.ipynb` | Retrieval e NMC | P@1 0.4812; NMC 0.4185 |
#
# Il notebook storico e' conservato separatamente in `exploratory/Esperimenti_di_prova.ipynb`.

# %% [markdown]
# ## Risultato sintetico
#
# ![Confronto accuracy](figures/gtsrb_test_accuracy_comparison.svg)
#
# Fonti numeriche: [`results/test_metrics.csv`](results/test_metrics.csv).

# %% [markdown]
# ## Funzioni, classi e moduli locali richiamati
#
# La tabella è ricavata dagli import, dagli utilizzi nelle celle e dalle definizioni effettive nei package locali.
#
# | Funzione o classe | Tipo | File di definizione | Scopo | Input principali | Output principali | Sezione |
# | ----------------- | ---- | ------------------- | ----- | ---------------- | ----------------- | ------- |
# | Nessuna funzione locale (notebook indice) | — | — | Collega documentazione e notebook tecnici. | — | — | Indice |
