# %% [markdown]
# # DLA 2 - Transformer e CLIP
#
# Autore: Francesco Faggioli
# Corso: Deep Learning Applications
#
# [Consegna ufficiale](ASSIGNMENT.md) | [Report tecnico](README.md)

# %% [markdown]
# > **Modalita' di consultazione**
# >
# > Questo notebook e' l'indice GitHub-ready. I notebook dettagliati conservano gli output eseguiti; i flag `RUN_*` impediscono di rilanciare automaticamente training e preprocessing costosi.

# %% [markdown]
# ## Percorso finale
#
# | Notebook | Ruolo | Evidenza principale |
# | --- | --- | --- |
# | `notebooks/01_sentiment_dataset_tokenizer_baseline.ipynb` | Dataset, tokenizer, SVM | Accuracy di test 0.7946 |
# | `notebooks/02_distilbert_full_finetuning.ipynb` | Fine-tuning completo | Accuracy di test 0.8443 |
# | `notebooks/03_efficient_finetuning_sentiment.ipynb` | LoRA e freezing | LoRA 0.8386 con 1.09% trainabile |
# | `notebooks/04_clip_adapter_imagenet_sketch.ipynb` | CLIP-Adapter | Accuracy 0.5241 |

# %% [markdown]
# ## Risultato sintetico
#
# ![Confronto sentiment](figures/sentiment_test_accuracy.svg)
#
# Fonti numeriche: [`results/sentiment_results.csv`](results/sentiment_results.csv) e [`results/clip_results.csv`](results/clip_results.csv).

# %% [markdown]
# ## Funzioni, classi e moduli locali richiamati
#
# La tabella è ricavata dagli import, dagli utilizzi nelle celle e dalle definizioni effettive nei package locali.
#
# | Funzione o classe | Tipo | File di definizione | Scopo | Input principali | Output principali | Sezione |
# | ----------------- | ---- | ------------------- | ----- | ---------------- | ----------------- | ------- |
# | Nessuna funzione locale (notebook indice) | — | — | Collega documentazione e notebook tecnici. | — | — | Indice |
